# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
python
import os
for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        if file.endswith('.csv'):
            print(os.path.join(root, file))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1031/2344298676.py in <cell line: 0>()
# ----> 1 python
#       2 import os
#       3 for root, dirs, files in os.walk('/content/drive/MyDrive'):
#       4     for file in files:
#       5         if file.endswith('.csv'):
#
# NameError: name 'python' is not defined

# %%
import os
for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        if file.endswith('.csv'):
            print(os.path.join(root, file))

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/telco_churn.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1023/3869955606.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('/content/drive/MyDrive/telco_churn.csv')
#       4 df.head()
#
# ...

# %%
import os
for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        if 'telco' in file.lower() or 'churn' in file.lower():
            print(os.path.join(root, file))
# Out:
# /content/drive/MyDrive/WA_Fn-UseC_-Telco-Customer-Churn-selected-columns.csv

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/WA_Fn-UseC_-Telco-Customer-Churn-selected-columns.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity
# 0  No phone service             DSL             No
# 1                No             DSL            Yes
# 2                No             DSL            Yes
# 3  No phone service             DSL            Yes
# 4                No     Fiber optic             No

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity']

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/telco_churn_full.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1023/2273475533.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('/content/drive/MyDrive/telco_churn_full.csv')
#       4 df.head()
#
# ...

# %%
import os
for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        if 'churn' in file.lower() or 'telco' in file.lower():
            print(os.path.join(root, file))
# Out:
# /content/drive/MyDrive/WA_Fn-UseC_-Telco-Customer-Churn-selected-columns.csv

# %%
import os
for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        if file.endswith('.csv'):
            print(os.path.join(root, file))

# %%
import os
for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        print(os.path.join(root, file))

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1031/480459137.py in <cell line: 0>()
# ----> 1 drive.mount('/content/drive', force_remount=True)
#
# NameError: name 'drive' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        print(os.path.join(root, file))
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Document from anusankar216.pdf
# /content/drive/MyDrive/Document from anusankar216
# /content/drive/MyDrive/people management
# /content/drive/MyDrive/Share Reshma_ Resume .pdf
# /content/drive/MyDrive/Untitled document (5).gdoc
# /content/drive/MyDrive/Untitled document (4).gdoc
# /content/drive/MyDrive/anu .pdf
# /content/drive/MyDrive/Untitled document (3).gdoc
# /content/drive/MyDrive/Untitled document (2).gdoc
# /content/drive/MyDrive/Untitled document (1).gdoc
# /content/drive/MyDrive/Untitled document.gdoc
# /content/drive/MyDrive/Anu.pdf
# /content/drive/MyDrive/Anu img .gdoc
# /content/drive/MyDrive/Anu img .pdf
# /content/drive/MyDrive/Copy of anu .pdf
# /content/drive/MyDrive/Anu adhar.gdoc
# /content/drive/MyDrive/Anu adhar (1).pdf
# /content/drive/MyDrive/Anu adhar.pdf
# /content/drive/MyDrive/sch marksht.pdf
# /content/drive/MyDrive/university mrk.pdf
# /content/drive/MyDrive/Anu Signed pdf.pdf
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/telco_churn_full.csv')
df.head()


df.shape

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7,5))
sns.countplot(data=df, x='Contract', hue='Churn')
plt.title('Customer Churn by Contract Type')
plt.xlabel('Contract Type')
plt.ylabel('Number of Customers')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df, x='tenure', hue='Churn', multiple='stack', bins=20)
plt.title('Churn Distribution by Tenure')
plt.xlabel('Tenure (months)')
plt.ylabel('Number of Customers')
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(data=df, x='Churn', y='MonthlyCharges')
plt.title('Monthly Charges: Churned vs Retained Customers')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.show()
